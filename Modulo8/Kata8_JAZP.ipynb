# %% [markdown]
# Módulo8/Kata8
# Javier Zamora
# Administrar datos con diccionarios

# %% [markdown]
# Ejercicio 1: Creación de diccionarios de Python

# %%
planet = {
    'name': 'Mars',
    'moons': 2
}

# %%
print(f'{planet["name"]} has {planet["moons"]} moons')
# Out:
# Mars has 2 moons

# %%
planet['circumference (km)'] = {
    'polar': 6752,
    'equatorial': 6792
}

# %%
print(f'{planet["name"]} has a polar circumference of {planet["circumference (km)"]["polar"]}')
# Out:
# Mars has a polar circumference of 6752

# %% [markdown]
# Ejercicio 2: Programación dinámica con diccionarios

# %%
moons = planet_moons.values()
planets = len(planet_moons.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\javie\Desktop\LaunchX\Modulo8\Kata8_JAZP.ipynb Cell 8' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/javie/Desktop/LaunchX/Modulo8/Kata8_JAZP.ipynb#ch0000012?line=0'>1</a> moons = planet_moons.values()
#       <a href='vscode-notebook-cell:/c%3A/Users/javie/Desktop/LaunchX/Modulo8/Kata8_JAZP.ipynb#ch0000012?line=1'>2</a> planets = len(planet_moons.keys())
#
# NameError: name 'planet_moons' is not defined

# %%
total_moons = 0
for moon in moons:
    total_moons = total_moons + moon


average = total_moons / planets

print(average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\javie\Desktop\LaunchX\Modulo8\Kata8_JAZP.ipynb Cell 9' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/javie/Desktop/LaunchX/Modulo8/Kata8_JAZP.ipynb#ch0000013?line=0'>1</a> total_moons = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/javie/Desktop/LaunchX/Modulo8/Kata8_JAZP.ipynb#ch0000013?line=1'>2</a> for moon in moons:
#       <a href='vscode-notebook-cell:/c%3A/Users/javie/Desktop/LaunchX/Modulo8/Kata8_JAZP.ipynb#ch0000013?line=2'>3</a>     total_moons = total_moons + moon
#       <a href='vscode-notebook-cell:/c%3A/Users/javie/Desktop/LaunchX/Modulo8/Kata8_JAZP.ipynb#ch0000013?line=5'>6</a> average = total_moons / planets
#
# NameError: name 'moons' is not defined
